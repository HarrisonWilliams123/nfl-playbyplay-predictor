# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:/Users/harri/Documents/nfl-playbyplay-predictor/data/pbp_export.csv")

# %%
#Shows the first five plays of the 2020 NFL season
df.head()
# Out:
#    play_id         game_id  season play_type  down  ydstogo  yardline_100  \
# 0        1  2020_01_ARI_SF    2020       NaN   NaN        0           NaN
# 1       39  2020_01_ARI_SF    2020   kickoff   NaN        0          35.0
# 2       54  2020_01_ARI_SF    2020      pass   1.0       10          75.0
# 3       93  2020_01_ARI_SF    2020       run   1.0       10          55.0
# 4      118  2020_01_ARI_SF    2020       run   1.0       10          41.0
#
#    score_differential  game_seconds_remaining offense_personnel  \
# 0                 NaN                  3600.0               NaN
# 1                 0.0                  3600.0               NaN
# 2                 0.0                  3600.0  2 RB, 1 TE, 2 WR
# 3                 0.0                  3582.0  2 RB, 1 TE, 2 WR
# 4                 0.0                  3539.0  2 RB, 1 TE, 2 WR
#
#   defense_personnel posteam
# 0               NaN     NaN
# 1               NaN      SF
# 2  2 DL, 5 LB, 4 DB      SF
# ...

# %%
df.describe()
# Out:
#              play_id         season           down        ydstogo  \
# count  196726.000000  196726.000000  165330.000000  196726.000000
# mean     2117.833738    2021.513704       1.992155       7.101659
# std      1237.474701       1.113429       1.001704       4.861211
# min         1.000000    2020.000000       1.000000       0.000000
# 25%      1053.000000    2021.000000       1.000000       3.000000
# 50%      2103.000000    2022.000000       2.000000       9.000000
# 75%      3155.000000    2023.000000       3.000000      10.000000
# max      5523.000000    2023.000000       4.000000      43.000000
#
#         yardline_100  score_differential  game_seconds_remaining
# count  182854.000000       186098.000000           196713.000000
# mean       48.445388           -1.323023             1705.855480
# std        24.290279           10.472587             1059.715258
# min         1.000000          -56.000000                0.000000
# ...

# %%
df.columns
# Out:
# Index(['play_id', 'game_id', 'season', 'play_type', 'down', 'ydstogo',
#        'yardline_100', 'score_differential', 'game_seconds_remaining',
#        'offense_personnel', 'defense_personnel', 'posteam'],
#       dtype='str')

# %%
#Prints out the data types of each column
df.dtypes
# Out:
# play_id                     int64
# game_id                       str
# season                      int64
# play_type                     str
# down                      float64
# ydstogo                     int64
# yardline_100              float64
# score_differential        float64
# game_seconds_remaining    float64
# offense_personnel             str
# defense_personnel             str
# posteam                       str
# dtype: object

# %%
#Checks to see how many null values there are
df.isnull().sum()
# Out:
# play_id                       0
# game_id                       0
# season                        0
# play_type                  5728
# down                      31396
# ydstogo                       0
# yardline_100              13872
# score_differential        10628
# game_seconds_remaining       13
# offense_personnel         36742
# defense_personnel         36742
# posteam                   10628
# dtype: int64

# %%
#Prints out a correlation matrix of the numerical features
df.corr(numeric_only=True)
# Out:
#                          play_id    season      down   ydstogo  yardline_100  \
# play_id                 1.000000  0.007886  0.015196 -0.007268     -0.047674
# season                  0.007886  1.000000  0.017090  0.009000      0.018986
# down                    0.015196  0.017090  1.000000 -0.259130     -0.055793
# ydstogo                -0.007268  0.009000 -0.259130  1.000000      0.330132
# yardline_100           -0.047674  0.018986 -0.055793  0.330132      1.000000
# score_differential     -0.033306  0.003917  0.017165 -0.021009     -0.039164
# game_seconds_remaining -0.984008  0.000172 -0.019101  0.009333      0.061639
#
#                         score_differential  game_seconds_remaining
# play_id                          -0.033306               -0.984008
# season                            0.003917                0.000172
# down                              0.017165               -0.019101
# ydstogo                          -0.021009                0.009333
# ...
